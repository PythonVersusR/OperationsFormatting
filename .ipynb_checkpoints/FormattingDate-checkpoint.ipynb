# %% [markdown]
# # Formatting Data (dates)
#
# It is very common to find dates (some combination of year, month, day of week and time) in data that is collected in real time (and other that organize event information.
#
# Let's see a data frame that comes with dates from an API.

# %%
# !pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.2.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: requests>=2.28.1 in d:\users\jmagallanes\anaconda3\envs\pythonvsr\lib\site-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\jmagallanes\anaconda3\envs\pythonvsr\lib\site-packages (from requests>=2.28.1->sodapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\jmagallanes\anaconda3\envs\pythonvsr\lib\site-packages (from requests>=2.28.1->sodapy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\jmagallanes\anaconda3\envs\pythonvsr\lib\site-packages (from requests>=2.28.1->sodapy) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\jmagallanes\anaconda3\envs\pythonvsr\lib\site-packages (from requests>=2.28.1->sodapy) (2024.2.2)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.2.0

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.seattle.gov", None)

results = client.get("kzjm-xkqj", limit=2000)

# Convert to pandas DataFrame
calls911 = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# Let's check some information:

# %%
calls911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      2000 non-null   object
#  1   type                         2000 non-null   object
#  2   datetime                     2000 non-null   object
#  3   latitude                     2000 non-null   object
#  4   longitude                    2000 non-null   object
#  5   report_location              2000 non-null   object
#  6   incident_number              2000 non-null   object
#  7   :@computed_region_ru88_fbhk  1992 non-null   object
#  8   :@computed_region_kuhn_3gp2  1992 non-null   object
#  9   :@computed_region_q256_3sug  2000 non-null   object
#  10  :@computed_region_2day_rhn5  149 non-null    object
#  11  :@computed_region_cyqu_gs94  141 non-null    object
# dtypes: object(12)
# memory usage: 187.6+ KB

# %% [markdown]
# Let's get rid of some columns:

# %%
calls911=calls911.iloc[:,:7]

# %% [markdown]
# Let's check the column _datetime_:

# %%
calls911.datetime.head()
# Out:
# 0    2024-02-09T09:06:00.000
# 1    2024-02-09T09:05:00.000
# 2    2024-02-09T09:05:00.000
# 3    2024-02-09T08:50:00.000
# 4    2024-02-09T08:46:00.000
# Name: datetime, dtype: object

# %%
# then
type(calls911.datetime[0])
# Out:
# str

# %% [markdown]
# The date and time information is not useful at this time, that is, the information it offers is of limited use, as it is just a string.
#
# Let's make it useful:

# %%
calls911.datetime=pd.to_datetime(calls911.datetime)
calls911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          2000 non-null   object
#  1   type             2000 non-null   object
#  2   datetime         2000 non-null   datetime64[ns]
#  3   latitude         2000 non-null   object
#  4   longitude        2000 non-null   object
#  5   report_location  2000 non-null   object
#  6   incident_number  2000 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 109.5+ KB

# %%
calls911
# Out:
#                                  address                        type  \
# 0                         746 19th Ave E                Aid Response
# 1                       4225 Beach Dr Sw                Aid Response
# 2                     77 S Washington St                Aid Response
# 3                           400 Broad St  Automatic Fire Alarm False
# 4                        2802 Nw 91st St              Medic Response
# ...                                  ...                         ...
# 1995                         300 Pine St                Aid Response
# 1996                        2119 3rd Ave                Aid Response
# 1997                          808 Fir St                  Alarm Bell
# 1998                     2340 21st Ave S   Automatic Fire Alarm Resd
# 1999  S Mount Baker Blvd / Rainier Ave S                Aid Response
#
#                 datetime   latitude    longitude  \
# 0    2024-02-09 09:06:00  47.625602  -122.307314
# 1    2024-02-09 09:05:00  47.565587  -122.407826
# 2    2024-02-09 09:05:00  47.600885  -122.334925
# 3    2024-02-09 08:50:00  47.619744  -122.348859
# 4    2024-02-09 08:46:00   47.69532  -122.392919
# ...                  ...        ...          ...
# 1995 2024-02-03 13:52:00  47.610743  -122.338702
# 1996 2024-02-03 13:50:00  47.613308  -122.342432
# 1997 2024-02-03 13:44:00  47.602699  -122.322029
# 1998 2024-02-03 13:43:00  47.582554  -122.305564
# 1999 2024-02-03 13:40:00  47.575873  -122.296243
#
#                                         report_location incident_number
# 0     {'type': 'Point', 'coordinates': [-122.307314,...      F240020453
# 1     {'type': 'Point', 'coordinates': [-122.407826,...      F240020452
# 2     {'type': 'Point', 'coordinates': [-122.334925,...      F240020454
# 3     {'type': 'Point', 'coordinates': [-122.348859,...      F240020450
# 4     {'type': 'Point', 'coordinates': [-122.392919,...      F240020449
# ...                                                 ...             ...
# 1995  {'type': 'Point', 'coordinates': [-122.338702,...      F240017806
# 1996  {'type': 'Point', 'coordinates': [-122.342432,...      F240017805
# 1997  {'type': 'Point', 'coordinates': [-122.322029,...      F240017803
# 1998  {'type': 'Point', 'coordinates': [-122.305564,...      F240017802
# 1999  {'type': 'Point', 'coordinates': [-122.296243,...      F240017801
#
# [2000 rows x 7 columns]

# %% [markdown]
# Once you have this data type, you can retrieve important information:

# %%
calls911['date']=calls911.datetime.dt.date
calls911['year']=calls911.datetime.dt.year
calls911['month']=calls911.datetime.dt.month_name()
calls911['weekday']=calls911.datetime.dt.day_name()
calls911['hour']=calls911.datetime.dt.hour

# %%
calls911.head()
# Out:
#               address                        type            datetime  \
# 0      746 19th Ave E                Aid Response 2024-02-09 09:06:00
# 1    4225 Beach Dr Sw                Aid Response 2024-02-09 09:05:00
# 2  77 S Washington St                Aid Response 2024-02-09 09:05:00
# 3        400 Broad St  Automatic Fire Alarm False 2024-02-09 08:50:00
# 4     2802 Nw 91st St              Medic Response 2024-02-09 08:46:00
#
#     latitude    longitude                                    report_location  \
# 0  47.625602  -122.307314  {'type': 'Point', 'coordinates': [-122.307314,...
# 1  47.565587  -122.407826  {'type': 'Point', 'coordinates': [-122.407826,...
# 2  47.600885  -122.334925  {'type': 'Point', 'coordinates': [-122.334925,...
# 3  47.619744  -122.348859  {'type': 'Point', 'coordinates': [-122.348859,...
# 4   47.69532  -122.392919  {'type': 'Point', 'coordinates': [-122.392919,...
#
#   incident_number        date  year     month weekday  hour
# 0      F240020453  2024-02-09  2024  February  Friday     9
# 1      F240020452  2024-02-09  2024  February  Friday     9
# 2      F240020454  2024-02-09  2024  February  Friday     9
# 3      F240020450  2024-02-09  2024  February  Friday     8
# 4      F240020449  2024-02-09  2024  February  Friday     8

# %% [markdown]
# Let's create a new column with what we have. In this case, a boolean where you tell if it is night time (after 8 pm before 6 am):

# %%
calls911['nightTime']=((calls911['hour']<=6) | (calls911['hour']>=20))

# %% [markdown]
# Let's save what we have:

# %%
calls911
# Out:
#                      address                          type  \
# 0      4th Ave N / Mercer St              Triaged Incident
# 1          815 S Dearborn St    Investigate Out Of Service
# 2           9401 Myers Way S              Triaged Incident
# 3           11030 5th Ave Ne               Auto Fire Alarm
# 4         3013 Harvard Ave E  MVI - Motor Vehicle Incident
# ...                      ...                           ...
# 1995          1236 S King St                  Aid Response
# 1996  6312 California Ave Sw                Medic Response
# 1997         1023 E Alder St               Auto Fire Alarm
# 1998            1401 2nd Ave                  Aid Response
# 1999         4111 30th Ave S           Low Acuity Response
#
#                 datetime   latitude    longitude  \
# 0    2022-08-18 10:15:00  47.624564  -122.348877
# 1    2022-08-18 10:08:00  47.595831  -122.322292
# 2    2022-08-18 10:07:00  47.518658  -122.333265
# 3    2022-08-18 09:11:00  47.709488  -122.323301
# 4    2022-08-18 09:06:00  47.647935  -122.322101
# ...                  ...        ...          ...
# 1995 2022-08-12 12:07:00  47.598337  -122.316533
# 1996 2022-08-12 12:02:00  47.546604  -122.387196
# 1997 2022-08-12 12:00:00   47.60436  -122.319104
# 1998 2022-08-12 11:58:00  47.608292  -122.337995
# 1999 2022-08-12 11:55:00  47.566172  -122.295803
#
#                                         report_location incident_number  \
# 0     {'type': 'Point', 'coordinates': [-122.348877,...      F220099503
# 1     {'type': 'Point', 'coordinates': [-122.322292,...      F220099502
# 2     {'type': 'Point', 'coordinates': [-122.333265,...      F220099501
# 3     {'type': 'Point', 'coordinates': [-122.323301,...      F220099179
# 4     {'type': 'Point', 'coordinates': [-122.322101,...      F220099178
# ...                                                 ...             ...
# 1995  {'type': 'Point', 'coordinates': [-122.316533,...      F220096444
# 1996  {'type': 'Point', 'coordinates': [-122.387196,...      F220096443
# 1997  {'type': 'Point', 'coordinates': [-122.319104,...      F220096442
# 1998  {'type': 'Point', 'coordinates': [-122.337995,...      F220096441
# 1999  {'type': 'Point', 'coordinates': [-122.295803,...      F220096440
#
#             date  year   month   weekday  hour  nightTime
# 0     2022-08-18  2022  August  Thursday    10      False
# 1     2022-08-18  2022  August  Thursday    10      False
# 2     2022-08-18  2022  August  Thursday    10      False
# 3     2022-08-18  2022  August  Thursday     9      False
# 4     2022-08-18  2022  August  Thursday     9      False
# ...          ...   ...     ...       ...   ...        ...
# 1995  2022-08-12  2022  August    Friday    12      False
# 1996  2022-08-12  2022  August    Friday    12      False
# 1997  2022-08-12  2022  August    Friday    12      False
# 1998  2022-08-12  2022  August    Friday    11      False
# 1999  2022-08-12  2022  August    Friday    11      False
#
# [2000 rows x 13 columns]

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in d:\users\jmagallanes\anaconda3\envs\pythonvsr\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in d:\users\jmagallanes\anaconda3\envs\pythonvsr\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
link="https://es.wikipedia.org/wiki/Pandemia_de_COVID-19"

import pandas as pd

covid=pd.read_html(link, flavor="bs4", attrs={"class":"wikitable sortable"})

# %%
covidDF=covid[1].copy()
covidDF
# Out:
#            Territorios   Territorios.1  \
# 0              Bérgamo          Italia
# 1              Ginebra           Suiza
# 2               España          Europa
# 3            Karnataka           India
# 4               México         América
# 5          Nueva Delhi           India
# 6  Nueva York (ciudad)  Estados Unidos
# 7  Nueva York (estado)  Estados Unidos
# 8          Reino Unido          Europa
#
#                           Fecha del análisis Porcentaje con anticuerpos  \
# 0   23 de abril de 2020 a 3 de junio de 2020                        57%
# 1     6 de abril de 2020 a 9 de mayo de 2020                      10,9%
# 2                    15 de diciembre de 2020                       9,9%
# 3                   16 de septiembre de 2020                      27,3%
# 4                    16 de diciembre de 2020                      25,0%
# 5  27 de junio de 2020 a 10 de julio de 2020                      23,5%
# 6  19 de abril de 2020 a 28 de abril de 2020                      22,7%
# 7  19 de abril de 2020 a 28 de abril de 2020                        14%
# 8                          noviembre de 2020                       8,8%
#
#   Personas que han sido infectadas     Referencia
# 0                          635 000         [123]​
# 1                           54 000  [124]​ [125]​
# 2                        4 700 000         [126]​
# 3                       19 300 000         [127]​
# 4                       32 000 000         [128]​
# 5                        5 111 000         [129]​
# 6                        1 907 000  [130]​ [125]​
# 7                        2 139 000         [130]​
# 8                        5 900 000         [131]​

# %%
covidDF.columns
# Out:
# Index(['Territorios', 'Territorios.1', 'Fecha del análisis',
#        'Porcentaje con anticuerpos', 'Personas que han sido infectadas',
#        'Referencia'],
#       dtype='object')

# %%
import unidecode as ud

[ud.unidecode(c) for c in covidDF.columns]
# Out:
# ['Territorios',
#  'Territorios.1',
#  'Fecha del analisis',
#  'Porcentaje con anticuerpos',
#  'Personas que han sido infectadas',
#  'Referencia']

# %%
covidDF.columns=[ud.unidecode(c) for c in covidDF.columns]

# %%
covidDF.columns=covidDF.columns.str.replace("\\s","",regex=True).str.strip()

# %%
covidDF.Fechadelanalisis.str.split(" a ",expand=True)
# Out:
#                           0                    1
# 0       23 de abril de 2020   3 de junio de 2020
# 1        6 de abril de 2020    9 de mayo de 2020
# 2   15 de diciembre de 2020                 None
# 3  16 de septiembre de 2020                 None
# 4   16 de diciembre de 2020                 None
# 5       27 de junio de 2020  10 de julio de 2020
# 6       19 de abril de 2020  28 de abril de 2020
# 7       19 de abril de 2020  28 de abril de 2020
# 8         noviembre de 2020                 None

# %%
covidDF[["fecha1","fecha2"]]=covidDF.Fechadelanalisis.str.split(" a ",expand=True)
covidDF
# Out:
#            Territorios   Territorios.1  \
# 0              Bérgamo          Italia
# 1              Ginebra           Suiza
# 2               España          Europa
# 3            Karnataka           India
# 4               México         América
# 5          Nueva Delhi           India
# 6  Nueva York (ciudad)  Estados Unidos
# 7  Nueva York (estado)  Estados Unidos
# 8          Reino Unido          Europa
#
#                             Fechadelanalisis Porcentajeconanticuerpos  \
# 0   23 de abril de 2020 a 3 de junio de 2020                      57%
# 1     6 de abril de 2020 a 9 de mayo de 2020                    10,9%
# 2                    15 de diciembre de 2020                     9,9%
# 3                   16 de septiembre de 2020                    27,3%
# 4                    16 de diciembre de 2020                    25,0%
# 5  27 de junio de 2020 a 10 de julio de 2020                    23,5%
# 6  19 de abril de 2020 a 28 de abril de 2020                    22,7%
# 7  19 de abril de 2020 a 28 de abril de 2020                      14%
# 8                          noviembre de 2020                     8,8%
#
#   Personasquehansidoinfectadas     Referencia                    fecha1  \
# 0                      635 000         [123]​       23 de abril de 2020
# 1                       54 000  [124]​ [125]​        6 de abril de 2020
# 2                    4 700 000         [126]​   15 de diciembre de 2020
# 3                   19 300 000         [127]​  16 de septiembre de 2020
# 4                   32 000 000         [128]​   16 de diciembre de 2020
# 5                    5 111 000         [129]​       27 de junio de 2020
# 6                    1 907 000  [130]​ [125]​       19 de abril de 2020
# 7                    2 139 000         [130]​       19 de abril de 2020
# 8                    5 900 000         [131]​         noviembre de 2020
#
#                 fecha2
# 0   3 de junio de 2020
# 1    9 de mayo de 2020
# 2                 None
# 3                 None
# 4                 None
# 5  10 de julio de 2020
# 6  28 de abril de 2020
# 7  28 de abril de 2020
# 8                 None

# %%
covidDF.fecha1
# Out:
# 0         23 de abril de 2020
# 1          6 de abril de 2020
# 2     15 de diciembre de 2020
# 3    16 de septiembre de 2020
# 4     16 de diciembre de 2020
# 5         27 de junio de 2020
# 6         19 de abril de 2020
# 7         19 de abril de 2020
# 8           noviembre de 2020
# Name: fecha1, dtype: object

# %%
covidDF.fecha1.str.split(" de ",expand=True)
# Out:
#            0           1     2
# 0         23       abril  2020
# 1          6       abril  2020
# 2         15   diciembre  2020
# 3         16  septiembre  2020
# 4         16   diciembre  2020
# 5         27       junio  2020
# 6         19       abril  2020
# 7         19       abril  2020
# 8  noviembre        2020  None

# %%
from googletrans import Translator
translator = Translator()
[translator.translate(x, src='es', dest='en') for x in covidDF.fecha1.str.split(" de ",expand=True).iloc[:,1]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 3
#       1 from googletrans import Translator
#       2 translator = Translator()
# ----> 3 [translator.translate(x, src='es', dest='en') for x in covidDF.fecha1.str.split(" de ",expand=True).iloc[:,1]]
#
# Cell In[47], line 3, in <listcomp>(.0)
#       1 from googletrans import Translator
#       2 translator = Translator()
# ----> 3 [translator.translate(x, src='es', dest='en') for x in covidDF.fecha1.str.split(" de ",expand=True).iloc[:,1]]
#
# File ~\Anaconda3\envs\PythonvsR\Lib\site-packages\googletrans\client.py:172, in Translator.translate(self, text, dest, src)
#     169     return result
#     171 origin = text
# --> 172 data = self._translate(text, dest, src)
#     174 # this code will be updated when the format is changed.
#     175 translated = ''.join([d[0] if d[0] else '' for d in data[0]])
#
# File ~\Anaconda3\envs\PythonvsR\Lib\site-packages\googletrans\client.py:75, in Translator._translate(self, text, dest, src)
#      72 if not PY3 and isinstance(text, str):  # pragma: nocover
#      73     text = text.decode('utf-8')
# ---> 75 token = self.token_acquirer.do(text)
#      76 params = utils.build_params(query=text, src=src, dest=dest,
#      77                             token=token)
#      78 url = urls.TRANSLATE.format(host=self._pick_service_url())
#
# File ~\Anaconda3\envs\PythonvsR\Lib\site-packages\googletrans\gtoken.py:200, in TokenAcquirer.do(self, text)
#     199 def do(self, text):
# --> 200     self._update()
#     201     tk = self.acquire(text)
#     202     return tk
#
# File ~\Anaconda3\envs\PythonvsR\Lib\site-packages\googletrans\gtoken.py:65, in TokenAcquirer._update(self)
#      62     return
#      64 # this will be the same as python code after stripping out a reserved word 'var'
# ---> 65 code = unicode(self.RE_TKK.search(r.text).group(1)).replace('var ', '')
#      66 # unescape special ascii characters such like a \x3d(=)
#      67 if PY3:  # pragma: no cover
#
# AttributeError: 'NoneType' object has no attribute 'group'
